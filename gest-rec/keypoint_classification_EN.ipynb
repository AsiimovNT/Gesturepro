# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42
# Out:
# 2024-06-01 09:51:56.682972: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-01 09:52:04.013437: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-01 09:52:04.013466: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-01 09:52:04.776123: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-01 09:52:05.659204: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-01 09:52:12.009287: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Specify each path

# %%
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

# %% [markdown]
# # Set number of classes

# %%
NUM_CLASSES = 5

# %% [markdown]
# # Dataset reading

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # Model building

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# 2024-06-01 09:52:24.353450: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-01 09:52:31.974116: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-01 09:52:31.974263: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-01 09:52:31.975663: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-01 09:52:31.975763: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-01 09:52:31.975834: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-01 09:52:32.019229: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-01 09:52:32.019354: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-01 09:52:32.019438: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-01 09:52:32.019504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2243 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout (Dropout)           (None, 42)                0
#
#  dense (Dense)               (None, 20)                860
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 5)                 55
#
# =================================================================
# Total params: 1125 (4.39 KB)
# Trainable params: 1125 (4.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Model checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# Callback for early stopping
#es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# Model compilation
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Model training

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback]
)
# Out:
# Epoch 1/1000
# 2024-06-01 09:52:34.962916: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-06-01 09:52:38.567462: I external/local_xla/xla/service/service.cc:168] XLA service 0x55cc47957880 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-06-01 09:52:38.567503: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-06-01 09:52:38.572835: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-01 09:52:39.010804: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717215759.111628    6858 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 20/31 [==================>...........] - ETA: 0s - loss: 1.5485 - accuracy: 0.2613
# Epoch 1: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 7s 9ms/step - loss: 1.5219 - accuracy: 0.2793 - val_loss: 1.4029 - val_accuracy: 0.3979
# Epoch 2/1000
# 23/31 [=====================>........] - ETA: 0s - loss: 1.4400 - accuracy: 0.3359
# Epoch 2: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# /home/deadsoul/.local/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 31/31 [==============================] - 0s 8ms/step - loss: 1.4299 - accuracy: 0.3392 - val_loss: 1.3286 - val_accuracy: 0.4116
# Epoch 3/1000
# 17/31 [===============>..............] - ETA: 0s - loss: 1.3821 - accuracy: 0.3594
# Epoch 3: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 1.3748 - accuracy: 0.3591 - val_loss: 1.2555 - val_accuracy: 0.4637
# Epoch 4/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 1.3242 - accuracy: 0.3963
# Epoch 4: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 1.3157 - accuracy: 0.4024 - val_loss: 1.1818 - val_accuracy: 0.5210
# Epoch 5/1000
# 19/31 [=================>............] - ETA: 0s - loss: 1.2697 - accuracy: 0.4260
# Epoch 5: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 1.2564 - accuracy: 0.4310 - val_loss: 1.0950 - val_accuracy: 0.5647
# Epoch 6/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 1.2282 - accuracy: 0.4254
# Epoch 6: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 1.2257 - accuracy: 0.4272 - val_loss: 1.0316 - val_accuracy: 0.5769
# Epoch 7/1000
# 18/31 [================>.............] - ETA: 0s - loss: 1.1688 - accuracy: 0.4518
# Epoch 7: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 1.1678 - accuracy: 0.4527 - val_loss: 0.9818 - val_accuracy: 0.5792
# Epoch 8/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 1.1506 - accuracy: 0.4654
# Epoch 8: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 1.1448 - accuracy: 0.4769 - val_loss: 0.9213 - val_accuracy: 0.6251
# Epoch 9/1000
# 11/31 [=========>....................] - ETA: 0s - loss: 1.1268 - accuracy: 0.4830
# Epoch 9: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 1.1078 - accuracy: 0.4930 - val_loss: 0.8826 - val_accuracy: 0.6565
# Epoch 10/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 1.0815 - accuracy: 0.4981
# Epoch 10: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 1.0735 - accuracy: 0.5126 - val_loss: 0.8357 - val_accuracy: 0.7138
# Epoch 11/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 1.0574 - accuracy: 0.5366
# Epoch 11: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 1.0577 - accuracy: 0.5343 - val_loss: 0.8040 - val_accuracy: 0.7613
# Epoch 12/1000
# 19/31 [=================>............] - ETA: 0s - loss: 1.0316 - accuracy: 0.5596
# Epoch 12: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 1.0216 - accuracy: 0.5649 - val_loss: 0.7653 - val_accuracy: 0.7827
# Epoch 13/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 1.0116 - accuracy: 0.5577
# Epoch 13: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 1.0074 - accuracy: 0.5590 - val_loss: 0.7363 - val_accuracy: 0.8057
# Epoch 14/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.9834 - accuracy: 0.5797
# Epoch 14: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.9886 - accuracy: 0.5817 - val_loss: 0.7101 - val_accuracy: 0.8202
# Epoch 15/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.9634 - accuracy: 0.6058
# Epoch 15: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.9652 - accuracy: 0.6016 - val_loss: 0.6903 - val_accuracy: 0.8164
# Epoch 16/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.9558 - accuracy: 0.5929
# Epoch 16: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.9651 - accuracy: 0.5838 - val_loss: 0.6702 - val_accuracy: 0.8240
# Epoch 17/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.9500 - accuracy: 0.5996
# Epoch 17: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.9438 - accuracy: 0.6004 - val_loss: 0.6530 - val_accuracy: 0.8171
# Epoch 18/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.9456 - accuracy: 0.5993
# Epoch 18: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.9337 - accuracy: 0.6083 - val_loss: 0.6361 - val_accuracy: 0.8294
# Epoch 19/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.9072 - accuracy: 0.6320
# Epoch 19: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.9074 - accuracy: 0.6307 - val_loss: 0.6177 - val_accuracy: 0.8409
# Epoch 20/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.8818 - accuracy: 0.6477
# Epoch 20: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8904 - accuracy: 0.6407 - val_loss: 0.6033 - val_accuracy: 0.8454
# Epoch 21/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.8985 - accuracy: 0.6317
# Epoch 21: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8835 - accuracy: 0.6343 - val_loss: 0.5810 - val_accuracy: 0.8500
# Epoch 22/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.8969 - accuracy: 0.6235
# Epoch 22: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8925 - accuracy: 0.6299 - val_loss: 0.5715 - val_accuracy: 0.8630
# Epoch 23/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.8692 - accuracy: 0.6508
# Epoch 23: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8647 - accuracy: 0.6496 - val_loss: 0.5581 - val_accuracy: 0.8699
# Epoch 24/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.8628 - accuracy: 0.6637
# Epoch 24: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8713 - accuracy: 0.6598 - val_loss: 0.5465 - val_accuracy: 0.8776
# Epoch 25/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.8672 - accuracy: 0.6581
# Epoch 25: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8499 - accuracy: 0.6631 - val_loss: 0.5333 - val_accuracy: 0.8829
# Epoch 26/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.8245 - accuracy: 0.6830
# Epoch 26: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8344 - accuracy: 0.6779 - val_loss: 0.5137 - val_accuracy: 0.8898
# Epoch 27/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.7953 - accuracy: 0.6930
# Epoch 27: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8110 - accuracy: 0.6868 - val_loss: 0.4993 - val_accuracy: 0.8921
# Epoch 28/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.8174 - accuracy: 0.6704
# Epoch 28: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8200 - accuracy: 0.6700 - val_loss: 0.4861 - val_accuracy: 0.8975
# Epoch 29/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.8194 - accuracy: 0.6733
# Epoch 29: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8112 - accuracy: 0.6812 - val_loss: 0.4781 - val_accuracy: 0.9021
# Epoch 30/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.7892 - accuracy: 0.6871
# Epoch 30: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7945 - accuracy: 0.6838 - val_loss: 0.4727 - val_accuracy: 0.8982
# Epoch 31/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.7969 - accuracy: 0.6953
# Epoch 31: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8089 - accuracy: 0.6889 - val_loss: 0.4677 - val_accuracy: 0.8944
# Epoch 32/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.8076 - accuracy: 0.6779
# Epoch 32: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8069 - accuracy: 0.6789 - val_loss: 0.4652 - val_accuracy: 0.8959
# Epoch 33/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.7770 - accuracy: 0.7031
# Epoch 33: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7806 - accuracy: 0.6960 - val_loss: 0.4496 - val_accuracy: 0.9120
# Epoch 34/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.7903 - accuracy: 0.6920
# Epoch 34: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.8001 - accuracy: 0.6881 - val_loss: 0.4468 - val_accuracy: 0.9051
# Epoch 35/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.7857 - accuracy: 0.6898
# Epoch 35: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7811 - accuracy: 0.6978 - val_loss: 0.4444 - val_accuracy: 0.9059
# Epoch 36/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.7661 - accuracy: 0.7028
# Epoch 36: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7637 - accuracy: 0.6988 - val_loss: 0.4344 - val_accuracy: 0.9051
# Epoch 37/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.7822 - accuracy: 0.6801
# Epoch 37: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7730 - accuracy: 0.6901 - val_loss: 0.4280 - val_accuracy: 0.9044
# Epoch 38/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.7590 - accuracy: 0.7088
# Epoch 38: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7549 - accuracy: 0.7070 - val_loss: 0.4186 - val_accuracy: 0.9166
# Epoch 39/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.7579 - accuracy: 0.7117
# Epoch 39: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7605 - accuracy: 0.7113 - val_loss: 0.4135 - val_accuracy: 0.9143
# Epoch 40/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.7532 - accuracy: 0.7028
# Epoch 40: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7654 - accuracy: 0.6998 - val_loss: 0.4034 - val_accuracy: 0.9204
# Epoch 41/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.7577 - accuracy: 0.7045
# Epoch 41: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7568 - accuracy: 0.7070 - val_loss: 0.4023 - val_accuracy: 0.9135
# Epoch 42/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.7422 - accuracy: 0.7184
# Epoch 42: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7386 - accuracy: 0.7172 - val_loss: 0.3960 - val_accuracy: 0.9112
# Epoch 43/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.7213 - accuracy: 0.7307
# Epoch 43: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7220 - accuracy: 0.7297 - val_loss: 0.3868 - val_accuracy: 0.9166
# Epoch 44/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.7343 - accuracy: 0.7171
# Epoch 44: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7289 - accuracy: 0.7263 - val_loss: 0.3887 - val_accuracy: 0.9227
# Epoch 45/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.7183 - accuracy: 0.7281
# Epoch 45: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7277 - accuracy: 0.7269 - val_loss: 0.3736 - val_accuracy: 0.9220
# Epoch 46/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.7211 - accuracy: 0.7258
# Epoch 46: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7277 - accuracy: 0.7228 - val_loss: 0.3771 - val_accuracy: 0.9204
# Epoch 47/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.7021 - accuracy: 0.7266
# Epoch 47: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7034 - accuracy: 0.7289 - val_loss: 0.3661 - val_accuracy: 0.9265
# Epoch 48/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.7036 - accuracy: 0.7336
# Epoch 48: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7013 - accuracy: 0.7335 - val_loss: 0.3693 - val_accuracy: 0.9174
# Epoch 49/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6896 - accuracy: 0.7422
# Epoch 49: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6981 - accuracy: 0.7437 - val_loss: 0.3617 - val_accuracy: 0.9235
# Epoch 50/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.7068 - accuracy: 0.7375
# Epoch 50: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7065 - accuracy: 0.7345 - val_loss: 0.3589 - val_accuracy: 0.9212
# Epoch 51/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.7112 - accuracy: 0.7246
# Epoch 51: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7124 - accuracy: 0.7251 - val_loss: 0.3570 - val_accuracy: 0.9235
# Epoch 52/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.7170 - accuracy: 0.7315
# Epoch 52: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7132 - accuracy: 0.7314 - val_loss: 0.3547 - val_accuracy: 0.9220
# Epoch 53/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.7122 - accuracy: 0.7273
# Epoch 53: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7000 - accuracy: 0.7358 - val_loss: 0.3511 - val_accuracy: 0.9212
# Epoch 54/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6676 - accuracy: 0.7500
# Epoch 54: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6742 - accuracy: 0.7473 - val_loss: 0.3468 - val_accuracy: 0.9243
# Epoch 55/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.7308 - accuracy: 0.7148
# Epoch 55: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7236 - accuracy: 0.7207 - val_loss: 0.3462 - val_accuracy: 0.9281
# Epoch 56/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6989 - accuracy: 0.7366
# Epoch 56: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6935 - accuracy: 0.7399 - val_loss: 0.3458 - val_accuracy: 0.9311
# Epoch 57/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6740 - accuracy: 0.7453
# Epoch 57: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6876 - accuracy: 0.7450 - val_loss: 0.3400 - val_accuracy: 0.9304
# Epoch 58/1000
# 17/31 [===============>..............] - ETA: 0s - loss: 0.7103 - accuracy: 0.7238
# Epoch 58: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6999 - accuracy: 0.7317 - val_loss: 0.3485 - val_accuracy: 0.9273
# Epoch 59/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6862 - accuracy: 0.7489
# Epoch 59: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6940 - accuracy: 0.7409 - val_loss: 0.3416 - val_accuracy: 0.9250
# Epoch 60/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6635 - accuracy: 0.7519
# Epoch 60: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6781 - accuracy: 0.7460 - val_loss: 0.3302 - val_accuracy: 0.9350
# Epoch 61/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6628 - accuracy: 0.7519
# Epoch 61: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6732 - accuracy: 0.7450 - val_loss: 0.3330 - val_accuracy: 0.9258
# Epoch 62/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6479 - accuracy: 0.7507
# Epoch 62: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6457 - accuracy: 0.7605 - val_loss: 0.3291 - val_accuracy: 0.9265
# Epoch 63/1000
# 24/31 [======================>.......] - ETA: 0s - loss: 0.6864 - accuracy: 0.7438
# Epoch 63: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6811 - accuracy: 0.7434 - val_loss: 0.3265 - val_accuracy: 0.9304
# Epoch 64/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6939 - accuracy: 0.7392
# Epoch 64: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6808 - accuracy: 0.7404 - val_loss: 0.3287 - val_accuracy: 0.9296
# Epoch 65/1000
# 18/31 [================>.............] - ETA: 0s - loss: 0.6839 - accuracy: 0.7383
# Epoch 65: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6790 - accuracy: 0.7432 - val_loss: 0.3319 - val_accuracy: 0.9258
# Epoch 66/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6476 - accuracy: 0.7443
# Epoch 66: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6541 - accuracy: 0.7432 - val_loss: 0.3258 - val_accuracy: 0.9265
# Epoch 67/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6732 - accuracy: 0.7492
# Epoch 67: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6735 - accuracy: 0.7518 - val_loss: 0.3147 - val_accuracy: 0.9304
# Epoch 68/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6874 - accuracy: 0.7385
# Epoch 68: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6799 - accuracy: 0.7434 - val_loss: 0.3200 - val_accuracy: 0.9273
# Epoch 69/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6896 - accuracy: 0.7390
# Epoch 69: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6662 - accuracy: 0.7496 - val_loss: 0.3187 - val_accuracy: 0.9288
# Epoch 70/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.6608 - accuracy: 0.7562
# Epoch 70: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6495 - accuracy: 0.7592 - val_loss: 0.3175 - val_accuracy: 0.9288
# Epoch 71/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.6507 - accuracy: 0.7570
# Epoch 71: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6709 - accuracy: 0.7544 - val_loss: 0.3217 - val_accuracy: 0.9265
# Epoch 72/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6446 - accuracy: 0.7671
# Epoch 72: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6497 - accuracy: 0.7595 - val_loss: 0.3155 - val_accuracy: 0.9296
# Epoch 73/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6496 - accuracy: 0.7550
# Epoch 73: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6415 - accuracy: 0.7585 - val_loss: 0.3137 - val_accuracy: 0.9327
# Epoch 74/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6574 - accuracy: 0.7478
# Epoch 74: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6627 - accuracy: 0.7467 - val_loss: 0.3135 - val_accuracy: 0.9265
# Epoch 75/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6415 - accuracy: 0.7574
# Epoch 75: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6467 - accuracy: 0.7567 - val_loss: 0.3139 - val_accuracy: 0.9281
# Epoch 76/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6591 - accuracy: 0.7604
# Epoch 76: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6494 - accuracy: 0.7605 - val_loss: 0.3127 - val_accuracy: 0.9288
# Epoch 77/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6607 - accuracy: 0.7563
# Epoch 77: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6435 - accuracy: 0.7641 - val_loss: 0.3118 - val_accuracy: 0.9281
# Epoch 78/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6632 - accuracy: 0.7496
# Epoch 78: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6571 - accuracy: 0.7496 - val_loss: 0.3120 - val_accuracy: 0.9281
# Epoch 79/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6557 - accuracy: 0.7560
# Epoch 79: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6565 - accuracy: 0.7564 - val_loss: 0.3120 - val_accuracy: 0.9296
# Epoch 80/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6671 - accuracy: 0.7486
# Epoch 80: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6627 - accuracy: 0.7501 - val_loss: 0.3094 - val_accuracy: 0.9288
# Epoch 81/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6297 - accuracy: 0.7623
# Epoch 81: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6237 - accuracy: 0.7674 - val_loss: 0.3104 - val_accuracy: 0.9273
# Epoch 82/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6311 - accuracy: 0.7600
# Epoch 82: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6255 - accuracy: 0.7649 - val_loss: 0.3059 - val_accuracy: 0.9281
# Epoch 83/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.6183 - accuracy: 0.7760
# Epoch 83: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6217 - accuracy: 0.7697 - val_loss: 0.3049 - val_accuracy: 0.9281
# Epoch 84/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6618 - accuracy: 0.7565
# Epoch 84: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6596 - accuracy: 0.7567 - val_loss: 0.3076 - val_accuracy: 0.9273
# Epoch 85/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6563 - accuracy: 0.7593
# Epoch 85: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6509 - accuracy: 0.7633 - val_loss: 0.3105 - val_accuracy: 0.9288
# Epoch 86/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6368 - accuracy: 0.7589
# Epoch 86: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6352 - accuracy: 0.7615 - val_loss: 0.3038 - val_accuracy: 0.9281
# Epoch 87/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6295 - accuracy: 0.7664
# Epoch 87: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6310 - accuracy: 0.7651 - val_loss: 0.2994 - val_accuracy: 0.9288
# Epoch 88/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6387 - accuracy: 0.7684
# Epoch 88: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6467 - accuracy: 0.7628 - val_loss: 0.3029 - val_accuracy: 0.9265
# Epoch 89/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6197 - accuracy: 0.7706
# Epoch 89: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6286 - accuracy: 0.7651 - val_loss: 0.2977 - val_accuracy: 0.9319
# Epoch 90/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6077 - accuracy: 0.7746
# Epoch 90: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6141 - accuracy: 0.7771 - val_loss: 0.2966 - val_accuracy: 0.9281
# Epoch 91/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.5941 - accuracy: 0.7858
# Epoch 91: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6127 - accuracy: 0.7761 - val_loss: 0.2862 - val_accuracy: 0.9311
# Epoch 92/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5833 - accuracy: 0.7824
# Epoch 92: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6027 - accuracy: 0.7751 - val_loss: 0.2887 - val_accuracy: 0.9311
# Epoch 93/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6223 - accuracy: 0.7653
# Epoch 93: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6367 - accuracy: 0.7603 - val_loss: 0.2883 - val_accuracy: 0.9296
# Epoch 94/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6299 - accuracy: 0.7646
# Epoch 94: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6275 - accuracy: 0.7659 - val_loss: 0.2918 - val_accuracy: 0.9319
# Epoch 95/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6019 - accuracy: 0.7734
# Epoch 95: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6107 - accuracy: 0.7710 - val_loss: 0.2883 - val_accuracy: 0.9288
# Epoch 96/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6127 - accuracy: 0.7749
# Epoch 96: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6117 - accuracy: 0.7758 - val_loss: 0.2888 - val_accuracy: 0.9319
# Epoch 97/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6644 - accuracy: 0.7637
# Epoch 97: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6543 - accuracy: 0.7707 - val_loss: 0.2973 - val_accuracy: 0.9288
# Epoch 98/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6440 - accuracy: 0.7632
# Epoch 98: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6267 - accuracy: 0.7684 - val_loss: 0.2974 - val_accuracy: 0.9288
# Epoch 99/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6142 - accuracy: 0.7768
# Epoch 99: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6205 - accuracy: 0.7730 - val_loss: 0.2896 - val_accuracy: 0.9319
# Epoch 100/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6043 - accuracy: 0.7835
# Epoch 100: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6131 - accuracy: 0.7791 - val_loss: 0.2862 - val_accuracy: 0.9311
# Epoch 101/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6040 - accuracy: 0.7841
# Epoch 101: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6103 - accuracy: 0.7789 - val_loss: 0.2842 - val_accuracy: 0.9304
# Epoch 102/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6021 - accuracy: 0.7793
# Epoch 102: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6042 - accuracy: 0.7776 - val_loss: 0.2852 - val_accuracy: 0.9311
# Epoch 103/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6135 - accuracy: 0.7681
# Epoch 103: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6174 - accuracy: 0.7672 - val_loss: 0.2903 - val_accuracy: 0.9304
# Epoch 104/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6086 - accuracy: 0.7805
# Epoch 104: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6145 - accuracy: 0.7738 - val_loss: 0.2857 - val_accuracy: 0.9304
# Epoch 105/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6292 - accuracy: 0.7634
# Epoch 105: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6284 - accuracy: 0.7672 - val_loss: 0.2893 - val_accuracy: 0.9319
# Epoch 106/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6193 - accuracy: 0.7702
# Epoch 106: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6298 - accuracy: 0.7633 - val_loss: 0.2885 - val_accuracy: 0.9288
# Epoch 107/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6012 - accuracy: 0.7852
# Epoch 107: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5990 - accuracy: 0.7822 - val_loss: 0.2793 - val_accuracy: 0.9319
# Epoch 108/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5895 - accuracy: 0.7866
# Epoch 108: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6042 - accuracy: 0.7807 - val_loss: 0.2815 - val_accuracy: 0.9311
# Epoch 109/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6072 - accuracy: 0.7713
# Epoch 109: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6055 - accuracy: 0.7717 - val_loss: 0.2797 - val_accuracy: 0.9334
# Epoch 110/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6102 - accuracy: 0.7758
# Epoch 110: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6083 - accuracy: 0.7781 - val_loss: 0.2848 - val_accuracy: 0.9296
# Epoch 111/1000
# 23/31 [=====================>........] - ETA: 0s - loss: 0.5938 - accuracy: 0.7789
# Epoch 111: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5840 - accuracy: 0.7837 - val_loss: 0.2829 - val_accuracy: 0.9304
# Epoch 112/1000
# 18/31 [================>.............] - ETA: 0s - loss: 0.6024 - accuracy: 0.7847
# Epoch 112: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6010 - accuracy: 0.7845 - val_loss: 0.2831 - val_accuracy: 0.9288
# Epoch 113/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5778 - accuracy: 0.7783
# Epoch 113: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5745 - accuracy: 0.7822 - val_loss: 0.2747 - val_accuracy: 0.9334
# Epoch 114/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6159 - accuracy: 0.7746
# Epoch 114: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6016 - accuracy: 0.7791 - val_loss: 0.2755 - val_accuracy: 0.9357
# Epoch 115/1000
# 14/31 [============>.................] - ETA: 0s - loss: 0.6006 - accuracy: 0.7757
# Epoch 115: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6052 - accuracy: 0.7753 - val_loss: 0.2778 - val_accuracy: 0.9342
# Epoch 116/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5927 - accuracy: 0.7766
# Epoch 116: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6035 - accuracy: 0.7740 - val_loss: 0.2772 - val_accuracy: 0.9357
# Epoch 117/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6314 - accuracy: 0.7710
# Epoch 117: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6156 - accuracy: 0.7796 - val_loss: 0.2786 - val_accuracy: 0.9327
# Epoch 118/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5985 - accuracy: 0.7795
# Epoch 118: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6062 - accuracy: 0.7794 - val_loss: 0.2808 - val_accuracy: 0.9304
# Epoch 119/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.6293 - accuracy: 0.7567
# Epoch 119: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6090 - accuracy: 0.7649 - val_loss: 0.2796 - val_accuracy: 0.9357
# Epoch 120/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.5976 - accuracy: 0.7729
# Epoch 120: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5989 - accuracy: 0.7725 - val_loss: 0.2813 - val_accuracy: 0.9304
# Epoch 121/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5959 - accuracy: 0.7848
# Epoch 121: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6022 - accuracy: 0.7870 - val_loss: 0.2782 - val_accuracy: 0.9342
# Epoch 122/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6067 - accuracy: 0.7777
# Epoch 122: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5990 - accuracy: 0.7756 - val_loss: 0.2761 - val_accuracy: 0.9319
# Epoch 123/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5720 - accuracy: 0.7939
# Epoch 123: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5783 - accuracy: 0.7921 - val_loss: 0.2744 - val_accuracy: 0.9304
# Epoch 124/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5847 - accuracy: 0.7766
# Epoch 124: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5928 - accuracy: 0.7751 - val_loss: 0.2751 - val_accuracy: 0.9288
# Epoch 125/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.6041 - accuracy: 0.7867
# Epoch 125: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5975 - accuracy: 0.7881 - val_loss: 0.2783 - val_accuracy: 0.9334
# Epoch 126/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5968 - accuracy: 0.7879
# Epoch 126: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.7840 - val_loss: 0.2715 - val_accuracy: 0.9365
# Epoch 127/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5864 - accuracy: 0.7926
# Epoch 127: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5914 - accuracy: 0.7870 - val_loss: 0.2722 - val_accuracy: 0.9357
# Epoch 128/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5899 - accuracy: 0.7805
# Epoch 128: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6016 - accuracy: 0.7774 - val_loss: 0.2712 - val_accuracy: 0.9380
# Epoch 129/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5674 - accuracy: 0.7965
# Epoch 129: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5726 - accuracy: 0.7929 - val_loss: 0.2711 - val_accuracy: 0.9334
# Epoch 130/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6246 - accuracy: 0.7715
# Epoch 130: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5946 - accuracy: 0.7799 - val_loss: 0.2730 - val_accuracy: 0.9350
# Epoch 131/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5942 - accuracy: 0.7788
# Epoch 131: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5998 - accuracy: 0.7774 - val_loss: 0.2764 - val_accuracy: 0.9327
# Epoch 132/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5943 - accuracy: 0.7730
# Epoch 132: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5921 - accuracy: 0.7733 - val_loss: 0.2732 - val_accuracy: 0.9327
# Epoch 133/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5777 - accuracy: 0.7935
# Epoch 133: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5904 - accuracy: 0.7898 - val_loss: 0.2769 - val_accuracy: 0.9334
# Epoch 134/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5823 - accuracy: 0.7905
# Epoch 134: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5824 - accuracy: 0.7888 - val_loss: 0.2735 - val_accuracy: 0.9365
# Epoch 135/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5998 - accuracy: 0.7827
# Epoch 135: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5948 - accuracy: 0.7794 - val_loss: 0.2723 - val_accuracy: 0.9327
# Epoch 136/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5783 - accuracy: 0.7906
# Epoch 136: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5802 - accuracy: 0.7896 - val_loss: 0.2666 - val_accuracy: 0.9380
# Epoch 137/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.5762 - accuracy: 0.7852
# Epoch 137: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5810 - accuracy: 0.7825 - val_loss: 0.2625 - val_accuracy: 0.9411
# Epoch 138/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5743 - accuracy: 0.7990
# Epoch 138: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5798 - accuracy: 0.7906 - val_loss: 0.2629 - val_accuracy: 0.9373
# Epoch 139/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5872 - accuracy: 0.7873
# Epoch 139: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5822 - accuracy: 0.7904 - val_loss: 0.2610 - val_accuracy: 0.9457
# Epoch 140/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6063 - accuracy: 0.7798
# Epoch 140: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5952 - accuracy: 0.7863 - val_loss: 0.2726 - val_accuracy: 0.9373
# Epoch 141/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5993 - accuracy: 0.7812
# Epoch 141: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6005 - accuracy: 0.7786 - val_loss: 0.2664 - val_accuracy: 0.9380
# Epoch 142/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5754 - accuracy: 0.7880
# Epoch 142: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5790 - accuracy: 0.7858 - val_loss: 0.2707 - val_accuracy: 0.9373
# Epoch 143/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5981 - accuracy: 0.7775
# Epoch 143: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6041 - accuracy: 0.7748 - val_loss: 0.2730 - val_accuracy: 0.9380
# Epoch 144/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.5723 - accuracy: 0.8016
# Epoch 144: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5778 - accuracy: 0.7906 - val_loss: 0.2744 - val_accuracy: 0.9357
# Epoch 145/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5888 - accuracy: 0.7902
# Epoch 145: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5792 - accuracy: 0.7924 - val_loss: 0.2671 - val_accuracy: 0.9357
# Epoch 146/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5670 - accuracy: 0.7917
# Epoch 146: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5652 - accuracy: 0.7916 - val_loss: 0.2714 - val_accuracy: 0.9388
# Epoch 147/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5936 - accuracy: 0.7876
# Epoch 147: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5914 - accuracy: 0.7870 - val_loss: 0.2724 - val_accuracy: 0.9365
# Epoch 148/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6032 - accuracy: 0.7830
# Epoch 148: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5882 - accuracy: 0.7891 - val_loss: 0.2676 - val_accuracy: 0.9334
# Epoch 149/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5979 - accuracy: 0.7805
# Epoch 149: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5944 - accuracy: 0.7840 - val_loss: 0.2711 - val_accuracy: 0.9373
# Epoch 150/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5948 - accuracy: 0.7824
# Epoch 150: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5880 - accuracy: 0.7807 - val_loss: 0.2709 - val_accuracy: 0.9396
# Epoch 151/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5753 - accuracy: 0.7926
# Epoch 151: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5713 - accuracy: 0.7911 - val_loss: 0.2744 - val_accuracy: 0.9380
# Epoch 152/1000
# 12/31 [==========>...................] - ETA: 0s - loss: 0.5634 - accuracy: 0.7884
# Epoch 152: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5678 - accuracy: 0.7911 - val_loss: 0.2619 - val_accuracy: 0.9380
# Epoch 153/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5926 - accuracy: 0.7922
# Epoch 153: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5825 - accuracy: 0.7916 - val_loss: 0.2620 - val_accuracy: 0.9419
# Epoch 154/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5703 - accuracy: 0.7876
# Epoch 154: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# ...
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4866 - accuracy: 0.8250 - val_loss: 0.2538 - val_accuracy: 0.9464
# Epoch 949/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.4943 - accuracy: 0.8301
# Epoch 949: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5061 - accuracy: 0.8233 - val_loss: 0.2558 - val_accuracy: 0.9487
# Epoch 950/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5309 - accuracy: 0.8199
# Epoch 950: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5226 - accuracy: 0.8217 - val_loss: 0.2640 - val_accuracy: 0.9464
# Epoch 951/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.4841 - accuracy: 0.8289
# Epoch 951: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4908 - accuracy: 0.8250 - val_loss: 0.2493 - val_accuracy: 0.9495
# Epoch 952/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.4872 - accuracy: 0.8257
# Epoch 952: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4982 - accuracy: 0.8258 - val_loss: 0.2675 - val_accuracy: 0.9434
# Epoch 953/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.4777 - accuracy: 0.8343
# Epoch 953: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4781 - accuracy: 0.8324 - val_loss: 0.2515 - val_accuracy: 0.9495
# Epoch 954/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.4868 - accuracy: 0.8342
# Epoch 954: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4872 - accuracy: 0.8314 - val_loss: 0.2355 - val_accuracy: 0.9549
# Epoch 955/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.4998 - accuracy: 0.8289
# Epoch 955: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5082 - accuracy: 0.8268 - val_loss: 0.2420 - val_accuracy: 0.9526
# Epoch 956/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.5140 - accuracy: 0.8099
# Epoch 956: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5121 - accuracy: 0.8146 - val_loss: 0.2576 - val_accuracy: 0.9480
# Epoch 957/1000
# 18/31 [================>.............] - ETA: 0s - loss: 0.4797 - accuracy: 0.8355
# Epoch 957: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4950 - accuracy: 0.8279 - val_loss: 0.2530 - val_accuracy: 0.9510
# Epoch 958/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.4741 - accuracy: 0.8339
# Epoch 958: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4971 - accuracy: 0.8248 - val_loss: 0.2503 - val_accuracy: 0.9487
# Epoch 959/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.4643 - accuracy: 0.8456
# Epoch 959: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4828 - accuracy: 0.8335 - val_loss: 0.2437 - val_accuracy: 0.9533
# Epoch 960/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.5111 - accuracy: 0.8223
# Epoch 960: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5108 - accuracy: 0.8240 - val_loss: 0.2384 - val_accuracy: 0.9541
# Epoch 961/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.5121 - accuracy: 0.8211
# Epoch 961: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5027 - accuracy: 0.8256 - val_loss: 0.2438 - val_accuracy: 0.9556
# Epoch 962/1000
# 17/31 [===============>..............] - ETA: 0s - loss: 0.5249 - accuracy: 0.8194
# Epoch 962: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5015 - accuracy: 0.8243 - val_loss: 0.2486 - val_accuracy: 0.9533
# Epoch 963/1000
# 23/31 [=====================>........] - ETA: 0s - loss: 0.4763 - accuracy: 0.8342
# Epoch 963: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4789 - accuracy: 0.8350 - val_loss: 0.2538 - val_accuracy: 0.9495
# Epoch 964/1000
# 18/31 [================>.............] - ETA: 0s - loss: 0.5275 - accuracy: 0.8086
# Epoch 964: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5047 - accuracy: 0.8184 - val_loss: 0.2516 - val_accuracy: 0.9441
# Epoch 965/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.5086 - accuracy: 0.8211
# Epoch 965: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.8210 - val_loss: 0.2501 - val_accuracy: 0.9480
# Epoch 966/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5052 - accuracy: 0.8281
# Epoch 966: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4923 - accuracy: 0.8330 - val_loss: 0.2513 - val_accuracy: 0.9472
# Epoch 967/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5077 - accuracy: 0.8246
# Epoch 967: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5050 - accuracy: 0.8279 - val_loss: 0.2423 - val_accuracy: 0.9503
# Epoch 968/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.4941 - accuracy: 0.8195
# Epoch 968: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4977 - accuracy: 0.8166 - val_loss: 0.2519 - val_accuracy: 0.9503
# Epoch 969/1000
# 14/31 [============>.................] - ETA: 0s - loss: 0.5009 - accuracy: 0.8276
# Epoch 969: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5123 - accuracy: 0.8250 - val_loss: 0.2577 - val_accuracy: 0.9464
# Epoch 970/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5135 - accuracy: 0.8238
# Epoch 970: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5022 - accuracy: 0.8273 - val_loss: 0.2512 - val_accuracy: 0.9487
# Epoch 971/1000
# 26/31 [========================>.....] - ETA: 0s - loss: 0.5104 - accuracy: 0.8221
# Epoch 971: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5151 - accuracy: 0.8202 - val_loss: 0.2561 - val_accuracy: 0.9464
# Epoch 972/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.4948 - accuracy: 0.8261
# Epoch 972: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4936 - accuracy: 0.8307 - val_loss: 0.2638 - val_accuracy: 0.9434
# Epoch 973/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.4998 - accuracy: 0.8277
# Epoch 973: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5012 - accuracy: 0.8245 - val_loss: 0.2515 - val_accuracy: 0.9487
# Epoch 974/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.4891 - accuracy: 0.8245
# Epoch 974: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4978 - accuracy: 0.8220 - val_loss: 0.2492 - val_accuracy: 0.9495
# Epoch 975/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.5109 - accuracy: 0.8248
# Epoch 975: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5102 - accuracy: 0.8238 - val_loss: 0.2649 - val_accuracy: 0.9441
# Epoch 976/1000
# 23/31 [=====================>........] - ETA: 0s - loss: 0.5041 - accuracy: 0.8264
# Epoch 976: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5129 - accuracy: 0.8240 - val_loss: 0.2646 - val_accuracy: 0.9434
# Epoch 977/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.5139 - accuracy: 0.8170
# Epoch 977: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5040 - accuracy: 0.8230 - val_loss: 0.2640 - val_accuracy: 0.9434
# Epoch 978/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.5024 - accuracy: 0.8174
# Epoch 978: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4875 - accuracy: 0.8222 - val_loss: 0.2527 - val_accuracy: 0.9503
# Epoch 979/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5008 - accuracy: 0.8227
# Epoch 979: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4903 - accuracy: 0.8276 - val_loss: 0.2515 - val_accuracy: 0.9510
# Epoch 980/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5116 - accuracy: 0.8289
# Epoch 980: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5118 - accuracy: 0.8266 - val_loss: 0.2461 - val_accuracy: 0.9518
# Epoch 981/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5140 - accuracy: 0.8203
# Epoch 981: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5000 - accuracy: 0.8220 - val_loss: 0.2498 - val_accuracy: 0.9495
# Epoch 982/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.4884 - accuracy: 0.8348
# Epoch 982: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5034 - accuracy: 0.8281 - val_loss: 0.2436 - val_accuracy: 0.9495
# Epoch 983/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.5107 - accuracy: 0.8094
# Epoch 983: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5025 - accuracy: 0.8217 - val_loss: 0.2562 - val_accuracy: 0.9457
# Epoch 984/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5056 - accuracy: 0.8156
# Epoch 984: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4963 - accuracy: 0.8210 - val_loss: 0.2518 - val_accuracy: 0.9487
# Epoch 985/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.4861 - accuracy: 0.8244
# Epoch 985: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4939 - accuracy: 0.8212 - val_loss: 0.2427 - val_accuracy: 0.9503
# Epoch 986/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.4839 - accuracy: 0.8313
# Epoch 986: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4767 - accuracy: 0.8355 - val_loss: 0.2591 - val_accuracy: 0.9419
# Epoch 987/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.5128 - accuracy: 0.8140
# Epoch 987: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5049 - accuracy: 0.8187 - val_loss: 0.2506 - val_accuracy: 0.9457
# Epoch 988/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.4973 - accuracy: 0.8188
# Epoch 988: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5052 - accuracy: 0.8215 - val_loss: 0.2504 - val_accuracy: 0.9480
# Epoch 989/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5101 - accuracy: 0.8188
# Epoch 989: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5227 - accuracy: 0.8123 - val_loss: 0.2559 - val_accuracy: 0.9487
# Epoch 990/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.4939 - accuracy: 0.8208
# Epoch 990: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4896 - accuracy: 0.8284 - val_loss: 0.2476 - val_accuracy: 0.9510
# Epoch 991/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.4925 - accuracy: 0.8230
# Epoch 991: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5193 - accuracy: 0.8136 - val_loss: 0.2812 - val_accuracy: 0.9357
# Epoch 992/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.4910 - accuracy: 0.8315
# Epoch 992: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5093 - accuracy: 0.8227 - val_loss: 0.2585 - val_accuracy: 0.9434
# Epoch 993/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5022 - accuracy: 0.8234
# Epoch 993: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4925 - accuracy: 0.8296 - val_loss: 0.2371 - val_accuracy: 0.9480
# Epoch 994/1000
# 20/31 [==================>...........] - ETA: 0s - loss: 0.5062 - accuracy: 0.8227
# Epoch 994: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5015 - accuracy: 0.8240 - val_loss: 0.2587 - val_accuracy: 0.9457
# Epoch 995/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.5107 - accuracy: 0.8137
# Epoch 995: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5108 - accuracy: 0.8166 - val_loss: 0.2655 - val_accuracy: 0.9449
# Epoch 996/1000
# 19/31 [=================>............] - ETA: 0s - loss: 0.4958 - accuracy: 0.8277
# Epoch 996: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5022 - accuracy: 0.8301 - val_loss: 0.2573 - val_accuracy: 0.9487
# Epoch 997/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.4877 - accuracy: 0.8250
# Epoch 997: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5040 - accuracy: 0.8220 - val_loss: 0.2609 - val_accuracy: 0.9426
# Epoch 998/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.5204 - accuracy: 0.8218
# Epoch 998: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5158 - accuracy: 0.8207 - val_loss: 0.2659 - val_accuracy: 0.9426
# Epoch 999/1000
# 18/31 [================>.............] - ETA: 0s - loss: 0.5103 - accuracy: 0.8307
# Epoch 999: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5121 - accuracy: 0.8273 - val_loss: 0.2587 - val_accuracy: 0.9373
# Epoch 1000/1000
# 18/31 [================>.............] - ETA: 0s - loss: 0.5064 - accuracy: 0.8225
# Epoch 1000: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5014 - accuracy: 0.8217 - val_loss: 0.2473 - val_accuracy: 0.9495

# %%
# Model evaluation
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.9495

# %%
# Loading the saved model
model = tf.keras.models.load_model(model_save_path)

# %%
# Inference test
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 0s 252ms/step
# [0.02636659 0.5374707  0.41371438 0.00121624 0.02123214]
# 1

# %% [markdown]
# # Confusion matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 41/41 [==============================] - 0s 730us/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       406
#            1       0.92      0.95      0.93       377
#            2       0.96      0.97      0.96       338
#            3       0.99      1.00      0.99        83
#            4       0.92      0.70      0.80       103
#
#     accuracy                           0.95      1307
#    macro avg       0.95      0.92      0.93      1307
# weighted avg       0.95      0.95      0.95      1307

# %% [markdown]
# # Convert to model for Tensorflow-Lite

# %%
# Save as a model dedicated to inference
model.save(model_save_path, include_optimizer=False)
# Out:
# /home/deadsoul/.local/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Transform model (quantization)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp3c4i2tuu/assets
# INFO:tensorflow:Assets written to: /tmp/tmp3c4i2tuu/assets
# 2024-06-01 11:55:23.484145: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-06-01 11:55:23.484187: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-06-01 11:55:23.484361: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp3c4i2tuu
# 2024-06-01 11:55:23.485105: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-06-01 11:55:23.485123: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp3c4i2tuu
# 2024-06-01 11:55:23.487535: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-06-01 11:55:23.515684: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp3c4i2tuu
# 2024-06-01 11:55:23.524233: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 39872 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 6, Total Ops 13, % non-converted = 46.15 %
#  * 6 ARITH ops
#
# - arith.constant:    6 occurrences  (f32: 6)
#
#
#
#   (f32: 3)
#   (f32: 1)
# 6588

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# %%
# Get I / O tensor
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# Inference implementation
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: user 146 µs, sys: 13 µs, total: 159 µs
# Wall time: 121 µs

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [0.02636658 0.53747076 0.4137142  0.00121624 0.02123214]
# 1

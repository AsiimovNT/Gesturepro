# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42
# Out:
# 2024-05-04 23:42:57.403481: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-04 23:42:57.447704: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-04 23:42:57.447751: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-04 23:42:57.449127: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-04 23:42:57.456189: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 23:42:58.583259: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Specify each path

# %%
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

# %% [markdown]
# # Set number of classes

# %%
NUM_CLASSES = 5

# %% [markdown]
# # Dataset reading

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # Model building

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# 2024-05-04 23:43:06.791448: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-04 23:43:14.705467: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-04 23:43:14.708782: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-04 23:43:14.711127: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-04 23:43:14.711297: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-04 23:43:14.711403: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-04 23:43:14.837410: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-04 23:43:14.837647: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-04 23:43:14.837775: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-04 23:43:14.837888: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2284 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout (Dropout)           (None, 42)                0
#
#  dense (Dense)               (None, 20)                860
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 5)                 55
#
# =================================================================
# Total params: 1125 (4.39 KB)
# Trainable params: 1125 (4.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Model checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# Callback for early stopping
#es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# Model compilation
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Model training

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback]
)
# Out:
# Epoch 1/1000
# 2024-05-04 23:43:19.909037: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-04 23:43:23.525365: I external/local_xla/xla/service/service.cc:168] XLA service 0x5620e00cac80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-04 23:43:23.596186: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-05-04 23:43:23.603015: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-04 23:43:24.475248: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714846404.691420   30670 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 27/31 [=========================>....] - ETA: 0s - loss: 1.5701 - accuracy: 0.2645
# Epoch 1: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 9s 28ms/step - loss: 1.5622 - accuracy: 0.2714 - val_loss: 1.4616 - val_accuracy: 0.4285
# Epoch 2/1000
# 15/31 [=============>................] - ETA: 0s - loss: 1.4781 - accuracy: 0.3448
# /home/deadsoul/.local/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 28/31 [==========================>...] - ETA: 0s - loss: 1.4584 - accuracy: 0.3440
# Epoch 2: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 1.4549 - accuracy: 0.3471 - val_loss: 1.3361 - val_accuracy: 0.4529
# Epoch 3/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 1.3804 - accuracy: 0.4111
# Epoch 3: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 1.3704 - accuracy: 0.4007 - val_loss: 1.2361 - val_accuracy: 0.5065
# Epoch 4/1000
# 24/31 [======================>.......] - ETA: 0s - loss: 1.3207 - accuracy: 0.4118
# Epoch 4: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 1.3134 - accuracy: 0.4178 - val_loss: 1.1518 - val_accuracy: 0.5295
# Epoch 5/1000
# 31/31 [==============================] - ETA: 0s - loss: 1.2498 - accuracy: 0.4509
# Epoch 5: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 1.2498 - accuracy: 0.4509 - val_loss: 1.0848 - val_accuracy: 0.5524
# Epoch 6/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 1.2073 - accuracy: 0.4788
# Epoch 6: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 1.2014 - accuracy: 0.4828 - val_loss: 1.0165 - val_accuracy: 0.6174
# Epoch 7/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 1.1757 - accuracy: 0.4997
# Epoch 7: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 1.1688 - accuracy: 0.5037 - val_loss: 0.9576 - val_accuracy: 0.6595
# Epoch 8/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 1.1410 - accuracy: 0.5159
# Epoch 8: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 1.1363 - accuracy: 0.5195 - val_loss: 0.9083 - val_accuracy: 0.6917
# Epoch 9/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 1.1043 - accuracy: 0.5454
# Epoch 9: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 1.0860 - accuracy: 0.5522 - val_loss: 0.8569 - val_accuracy: 0.7207
# Epoch 10/1000
# 31/31 [==============================] - ETA: 0s - loss: 1.0661 - accuracy: 0.5539
# Epoch 10: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 1.0661 - accuracy: 0.5539 - val_loss: 0.8197 - val_accuracy: 0.7506
# Epoch 11/1000
# 29/31 [===========================>..] - ETA: 0s - loss: 1.0282 - accuracy: 0.5746
# Epoch 11: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 1.0280 - accuracy: 0.5754 - val_loss: 0.7822 - val_accuracy: 0.8018
# Epoch 12/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 1.0073 - accuracy: 0.5848
# Epoch 12: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 1.0054 - accuracy: 0.5868 - val_loss: 0.7476 - val_accuracy: 0.8286
# Epoch 13/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.9891 - accuracy: 0.6096
# Epoch 13: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9863 - accuracy: 0.6118 - val_loss: 0.7134 - val_accuracy: 0.8523
# Epoch 14/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.9562 - accuracy: 0.6169
# Epoch 14: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9562 - accuracy: 0.6169 - val_loss: 0.6841 - val_accuracy: 0.8684
# Epoch 15/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.9574 - accuracy: 0.6090
# Epoch 15: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9574 - accuracy: 0.6090 - val_loss: 0.6639 - val_accuracy: 0.8646
# Epoch 16/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.9508 - accuracy: 0.6191
# Epoch 16: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9443 - accuracy: 0.6220 - val_loss: 0.6446 - val_accuracy: 0.8829
# Epoch 17/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.9224 - accuracy: 0.6381
# Epoch 17: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9200 - accuracy: 0.6389 - val_loss: 0.6206 - val_accuracy: 0.8914
# Epoch 18/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.8891 - accuracy: 0.6516
# Epoch 18: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.8880 - accuracy: 0.6537 - val_loss: 0.5980 - val_accuracy: 0.8914
# Epoch 19/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.8747 - accuracy: 0.6577
# Epoch 19: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.8687 - accuracy: 0.6628 - val_loss: 0.5788 - val_accuracy: 0.8921
# Epoch 20/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.8762 - accuracy: 0.6523
# Epoch 20: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.8766 - accuracy: 0.6521 - val_loss: 0.5673 - val_accuracy: 0.8990
# Epoch 21/1000
# 29/31 [===========================>..] - ETA: 0s - loss: 0.8404 - accuracy: 0.6748
# Epoch 21: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.8377 - accuracy: 0.6774 - val_loss: 0.5483 - val_accuracy: 0.8875
# Epoch 22/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.8514 - accuracy: 0.6666
# Epoch 22: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.8463 - accuracy: 0.6659 - val_loss: 0.5346 - val_accuracy: 0.8914
# Epoch 23/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.8420 - accuracy: 0.6701
# Epoch 23: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.8514 - accuracy: 0.6664 - val_loss: 0.5272 - val_accuracy: 0.8982
# Epoch 24/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.8358 - accuracy: 0.6715
# Epoch 24: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.8358 - accuracy: 0.6715 - val_loss: 0.5227 - val_accuracy: 0.8929
# Epoch 25/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.8159 - accuracy: 0.6807
# Epoch 25: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.8159 - accuracy: 0.6807 - val_loss: 0.5068 - val_accuracy: 0.9005
# Epoch 26/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.8319 - accuracy: 0.6737
# Epoch 26: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.8307 - accuracy: 0.6748 - val_loss: 0.5003 - val_accuracy: 0.8921
# Epoch 27/1000
# 17/31 [===============>..............] - ETA: 0s - loss: 0.8031 - accuracy: 0.6898
# Epoch 27: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7994 - accuracy: 0.6919 - val_loss: 0.4927 - val_accuracy: 0.8921
# Epoch 28/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.7796 - accuracy: 0.7108
# Epoch 28: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7796 - accuracy: 0.7108 - val_loss: 0.4763 - val_accuracy: 0.9090
# Epoch 29/1000
# 29/31 [===========================>..] - ETA: 0s - loss: 0.7939 - accuracy: 0.6937
# Epoch 29: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7984 - accuracy: 0.6922 - val_loss: 0.4713 - val_accuracy: 0.8952
# Epoch 30/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.7805 - accuracy: 0.6985
# Epoch 30: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7805 - accuracy: 0.6985 - val_loss: 0.4676 - val_accuracy: 0.8936
# Epoch 31/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.7693 - accuracy: 0.7065
# Epoch 31: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7686 - accuracy: 0.7077 - val_loss: 0.4517 - val_accuracy: 0.9181
# Epoch 32/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.7594 - accuracy: 0.7159
# Epoch 32: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7594 - accuracy: 0.7159 - val_loss: 0.4412 - val_accuracy: 0.9105
# Epoch 33/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7663 - accuracy: 0.6943
# Epoch 33: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7712 - accuracy: 0.6912 - val_loss: 0.4354 - val_accuracy: 0.9036
# Epoch 34/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.7728 - accuracy: 0.7057
# Epoch 34: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7728 - accuracy: 0.7057 - val_loss: 0.4331 - val_accuracy: 0.9212
# Epoch 35/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.7562 - accuracy: 0.7047
# Epoch 35: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7520 - accuracy: 0.7108 - val_loss: 0.4255 - val_accuracy: 0.9197
# Epoch 36/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.7487 - accuracy: 0.7174
# Epoch 36: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7487 - accuracy: 0.7174 - val_loss: 0.4159 - val_accuracy: 0.9189
# Epoch 37/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.7263 - accuracy: 0.7286
# Epoch 37: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7263 - accuracy: 0.7286 - val_loss: 0.4099 - val_accuracy: 0.9220
# Epoch 38/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.7548 - accuracy: 0.7154
# Epoch 38: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7568 - accuracy: 0.7144 - val_loss: 0.4135 - val_accuracy: 0.9181
# Epoch 39/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.7521 - accuracy: 0.7073
# Epoch 39: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7536 - accuracy: 0.7085 - val_loss: 0.4121 - val_accuracy: 0.9166
# Epoch 40/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7150 - accuracy: 0.7397
# Epoch 40: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7388 - accuracy: 0.7266 - val_loss: 0.4019 - val_accuracy: 0.9220
# Epoch 41/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7497 - accuracy: 0.7134
# Epoch 41: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7428 - accuracy: 0.7159 - val_loss: 0.4012 - val_accuracy: 0.9135
# Epoch 42/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7300 - accuracy: 0.7295
# Epoch 42: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7275 - accuracy: 0.7317 - val_loss: 0.3978 - val_accuracy: 0.9227
# Epoch 43/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7303 - accuracy: 0.7168
# Epoch 43: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7354 - accuracy: 0.7210 - val_loss: 0.3935 - val_accuracy: 0.9220
# Epoch 44/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7044 - accuracy: 0.7324
# Epoch 44: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7233 - accuracy: 0.7271 - val_loss: 0.3831 - val_accuracy: 0.9250
# Epoch 45/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7220 - accuracy: 0.7314
# Epoch 45: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7157 - accuracy: 0.7345 - val_loss: 0.3829 - val_accuracy: 0.9220
# Epoch 46/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7205 - accuracy: 0.7295
# Epoch 46: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7304 - accuracy: 0.7251 - val_loss: 0.3816 - val_accuracy: 0.9258
# Epoch 47/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.7044 - accuracy: 0.7427
# Epoch 47: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7044 - accuracy: 0.7427 - val_loss: 0.3808 - val_accuracy: 0.9220
# Epoch 48/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.7134 - accuracy: 0.7198
# Epoch 48: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7374 - accuracy: 0.7113 - val_loss: 0.3792 - val_accuracy: 0.9235
# Epoch 49/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7180 - accuracy: 0.7241
# Epoch 49: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7112 - accuracy: 0.7281 - val_loss: 0.3753 - val_accuracy: 0.9204
# Epoch 50/1000
# 25/31 [=======================>......] - ETA: 0s - loss: 0.6987 - accuracy: 0.7344
# Epoch 50: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7013 - accuracy: 0.7320 - val_loss: 0.3690 - val_accuracy: 0.9220
# Epoch 51/1000
# 17/31 [===============>..............] - ETA: 0s - loss: 0.6991 - accuracy: 0.7394
# Epoch 51: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7009 - accuracy: 0.7360 - val_loss: 0.3647 - val_accuracy: 0.9220
# Epoch 52/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.7207 - accuracy: 0.7276
# Epoch 52: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.7059 - accuracy: 0.7337 - val_loss: 0.3635 - val_accuracy: 0.9258
# Epoch 53/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.6999 - accuracy: 0.7406
# Epoch 53: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6846 - accuracy: 0.7457 - val_loss: 0.3569 - val_accuracy: 0.9265
# Epoch 54/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6968 - accuracy: 0.7409
# Epoch 54: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6968 - accuracy: 0.7409 - val_loss: 0.3557 - val_accuracy: 0.9258
# Epoch 55/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.6766 - accuracy: 0.7510
# Epoch 55: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6907 - accuracy: 0.7437 - val_loss: 0.3562 - val_accuracy: 0.9273
# Epoch 56/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6768 - accuracy: 0.7544
# Epoch 56: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6768 - accuracy: 0.7544 - val_loss: 0.3466 - val_accuracy: 0.9250
# Epoch 57/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.7376
# Epoch 57: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6935 - accuracy: 0.7376 - val_loss: 0.3502 - val_accuracy: 0.9250
# Epoch 58/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.6700 - accuracy: 0.7467
# Epoch 58: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6700 - accuracy: 0.7501 - val_loss: 0.3439 - val_accuracy: 0.9288
# Epoch 59/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.6614 - accuracy: 0.7586
# Epoch 59: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6703 - accuracy: 0.7567 - val_loss: 0.3395 - val_accuracy: 0.9288
# Epoch 60/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6678 - accuracy: 0.7437
# Epoch 60: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6678 - accuracy: 0.7437 - val_loss: 0.3400 - val_accuracy: 0.9250
# Epoch 61/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6709 - accuracy: 0.7383
# Epoch 61: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6709 - accuracy: 0.7383 - val_loss: 0.3334 - val_accuracy: 0.9288
# Epoch 62/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6790 - accuracy: 0.7529
# Epoch 62: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6790 - accuracy: 0.7529 - val_loss: 0.3350 - val_accuracy: 0.9250
# Epoch 63/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.6791 - accuracy: 0.7521
# Epoch 63: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6631 - accuracy: 0.7585 - val_loss: 0.3324 - val_accuracy: 0.9265
# Epoch 64/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.6527 - accuracy: 0.7564
# Epoch 64: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.6583 - accuracy: 0.7549 - val_loss: 0.3326 - val_accuracy: 0.9250
# Epoch 65/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.7085 - accuracy: 0.7397
# Epoch 65: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6900 - accuracy: 0.7503 - val_loss: 0.3320 - val_accuracy: 0.9258
# Epoch 66/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.7414
# Epoch 66: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6854 - accuracy: 0.7419 - val_loss: 0.3302 - val_accuracy: 0.9281
# Epoch 67/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6765 - accuracy: 0.7464
# Epoch 67: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.7462 - val_loss: 0.3200 - val_accuracy: 0.9296
# Epoch 68/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6682 - accuracy: 0.7496
# Epoch 68: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6682 - accuracy: 0.7496 - val_loss: 0.3214 - val_accuracy: 0.9296
# Epoch 69/1000
# 29/31 [===========================>..] - ETA: 0s - loss: 0.6506 - accuracy: 0.7602
# Epoch 69: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6499 - accuracy: 0.7603 - val_loss: 0.3162 - val_accuracy: 0.9304
# Epoch 70/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6761 - accuracy: 0.7531
# Epoch 70: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6761 - accuracy: 0.7531 - val_loss: 0.3231 - val_accuracy: 0.9304
# Epoch 71/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.6534 - accuracy: 0.7571
# Epoch 71: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.6566 - accuracy: 0.7567 - val_loss: 0.3205 - val_accuracy: 0.9288
# Epoch 72/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6568 - accuracy: 0.7600
# Epoch 72: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6568 - accuracy: 0.7600 - val_loss: 0.3139 - val_accuracy: 0.9319
# Epoch 73/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.6562 - accuracy: 0.7600
# Epoch 73: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6552 - accuracy: 0.7610 - val_loss: 0.3131 - val_accuracy: 0.9304
# Epoch 74/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6522 - accuracy: 0.7623
# Epoch 74: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6522 - accuracy: 0.7623 - val_loss: 0.3053 - val_accuracy: 0.9319
# Epoch 75/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6529 - accuracy: 0.7562
# Epoch 75: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6529 - accuracy: 0.7562 - val_loss: 0.3115 - val_accuracy: 0.9296
# Epoch 76/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6394 - accuracy: 0.7677
# Epoch 76: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6394 - accuracy: 0.7677 - val_loss: 0.3035 - val_accuracy: 0.9380
# Epoch 77/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6688 - accuracy: 0.7456
# Epoch 77: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6677 - accuracy: 0.7457 - val_loss: 0.3120 - val_accuracy: 0.9288
# Epoch 78/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6378 - accuracy: 0.7692
# Epoch 78: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6378 - accuracy: 0.7692 - val_loss: 0.3019 - val_accuracy: 0.9296
# Epoch 79/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6594 - accuracy: 0.7549
# Epoch 79: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6594 - accuracy: 0.7549 - val_loss: 0.3030 - val_accuracy: 0.9311
# Epoch 80/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6436 - accuracy: 0.7590
# Epoch 80: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6436 - accuracy: 0.7590 - val_loss: 0.3018 - val_accuracy: 0.9327
# Epoch 81/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6480 - accuracy: 0.7661
# Epoch 81: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6496 - accuracy: 0.7654 - val_loss: 0.3049 - val_accuracy: 0.9319
# Epoch 82/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6423 - accuracy: 0.7580
# Epoch 82: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6423 - accuracy: 0.7580 - val_loss: 0.2974 - val_accuracy: 0.9327
# Epoch 83/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6593 - accuracy: 0.7607
# Epoch 83: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6538 - accuracy: 0.7564 - val_loss: 0.3002 - val_accuracy: 0.9334
# Epoch 84/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6593 - accuracy: 0.7555
# Epoch 84: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6652 - accuracy: 0.7531 - val_loss: 0.3030 - val_accuracy: 0.9288
# Epoch 85/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6186 - accuracy: 0.7672
# Epoch 85: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6186 - accuracy: 0.7672 - val_loss: 0.2899 - val_accuracy: 0.9319
# Epoch 86/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6639 - accuracy: 0.7559
# Epoch 86: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6639 - accuracy: 0.7559 - val_loss: 0.3014 - val_accuracy: 0.9288
# Epoch 87/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6279 - accuracy: 0.7626
# Epoch 87: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6279 - accuracy: 0.7626 - val_loss: 0.2946 - val_accuracy: 0.9265
# Epoch 88/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6545 - accuracy: 0.7666
# Epoch 88: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6545 - accuracy: 0.7666 - val_loss: 0.2965 - val_accuracy: 0.9373
# Epoch 89/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6414 - accuracy: 0.7648
# Epoch 89: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6415 - accuracy: 0.7638 - val_loss: 0.3018 - val_accuracy: 0.9319
# Epoch 90/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.6380 - accuracy: 0.7693
# Epoch 90: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6391 - accuracy: 0.7682 - val_loss: 0.2960 - val_accuracy: 0.9380
# Epoch 91/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6195 - accuracy: 0.7687
# Epoch 91: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6195 - accuracy: 0.7687 - val_loss: 0.2857 - val_accuracy: 0.9357
# Epoch 92/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6377 - accuracy: 0.7636
# Epoch 92: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6377 - accuracy: 0.7636 - val_loss: 0.2885 - val_accuracy: 0.9373
# Epoch 93/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6318 - accuracy: 0.7729
# Epoch 93: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6310 - accuracy: 0.7733 - val_loss: 0.2856 - val_accuracy: 0.9373
# Epoch 94/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6343 - accuracy: 0.7707
# Epoch 94: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6343 - accuracy: 0.7707 - val_loss: 0.2939 - val_accuracy: 0.9342
# Epoch 95/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6367 - accuracy: 0.7693
# Epoch 95: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6343 - accuracy: 0.7702 - val_loss: 0.2947 - val_accuracy: 0.9350
# Epoch 96/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.7483
# Epoch 96: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6553 - accuracy: 0.7483 - val_loss: 0.2937 - val_accuracy: 0.9342
# Epoch 97/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6334 - accuracy: 0.7669
# Epoch 97: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6334 - accuracy: 0.7669 - val_loss: 0.2896 - val_accuracy: 0.9357
# Epoch 98/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6503 - accuracy: 0.7621
# Epoch 98: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6503 - accuracy: 0.7621 - val_loss: 0.2861 - val_accuracy: 0.9357
# Epoch 99/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6288 - accuracy: 0.7702
# Epoch 99: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6288 - accuracy: 0.7702 - val_loss: 0.2899 - val_accuracy: 0.9311
# Epoch 100/1000
# 24/31 [======================>.......] - ETA: 0s - loss: 0.6446 - accuracy: 0.7575
# Epoch 100: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6478 - accuracy: 0.7595 - val_loss: 0.2896 - val_accuracy: 0.9327
# Epoch 101/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6366 - accuracy: 0.7592
# Epoch 101: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6366 - accuracy: 0.7592 - val_loss: 0.2823 - val_accuracy: 0.9388
# Epoch 102/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6352 - accuracy: 0.7622
# Epoch 102: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6411 - accuracy: 0.7621 - val_loss: 0.2887 - val_accuracy: 0.9311
# Epoch 103/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.7529
# Epoch 103: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6400 - accuracy: 0.7529 - val_loss: 0.2836 - val_accuracy: 0.9365
# Epoch 104/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.7692
# Epoch 104: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6304 - accuracy: 0.7692 - val_loss: 0.2794 - val_accuracy: 0.9373
# Epoch 105/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.6310 - accuracy: 0.7674
# Epoch 105: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6283 - accuracy: 0.7679 - val_loss: 0.2846 - val_accuracy: 0.9373
# Epoch 106/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6087 - accuracy: 0.7832
# Epoch 106: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6173 - accuracy: 0.7768 - val_loss: 0.2807 - val_accuracy: 0.9350
# Epoch 107/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6186 - accuracy: 0.7755
# Epoch 107: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6188 - accuracy: 0.7758 - val_loss: 0.2728 - val_accuracy: 0.9396
# Epoch 108/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6426 - accuracy: 0.7711
# Epoch 108: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6417 - accuracy: 0.7707 - val_loss: 0.2723 - val_accuracy: 0.9380
# Epoch 109/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6234 - accuracy: 0.7707
# Epoch 109: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6234 - accuracy: 0.7707 - val_loss: 0.2714 - val_accuracy: 0.9441
# Epoch 110/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6163 - accuracy: 0.7833
# Epoch 110: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6207 - accuracy: 0.7817 - val_loss: 0.2786 - val_accuracy: 0.9396
# Epoch 111/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6153 - accuracy: 0.7651
# Epoch 111: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6153 - accuracy: 0.7651 - val_loss: 0.2703 - val_accuracy: 0.9434
# Epoch 112/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6137 - accuracy: 0.7738
# Epoch 112: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6137 - accuracy: 0.7738 - val_loss: 0.2797 - val_accuracy: 0.9365
# Epoch 113/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6242 - accuracy: 0.7680
# Epoch 113: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6211 - accuracy: 0.7692 - val_loss: 0.2697 - val_accuracy: 0.9373
# Epoch 114/1000
# 29/31 [===========================>..] - ETA: 0s - loss: 0.6032 - accuracy: 0.7783
# Epoch 114: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6024 - accuracy: 0.7789 - val_loss: 0.2683 - val_accuracy: 0.9396
# Epoch 115/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6293 - accuracy: 0.7661
# Epoch 115: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6293 - accuracy: 0.7661 - val_loss: 0.2778 - val_accuracy: 0.9373
# Epoch 116/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6094 - accuracy: 0.7760
# Epoch 116: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6119 - accuracy: 0.7740 - val_loss: 0.2751 - val_accuracy: 0.9380
# Epoch 117/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6170 - accuracy: 0.7695
# Epoch 117: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6170 - accuracy: 0.7692 - val_loss: 0.2758 - val_accuracy: 0.9388
# Epoch 118/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6296 - accuracy: 0.7664
# Epoch 118: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 8ms/step - loss: 0.6273 - accuracy: 0.7664 - val_loss: 0.2744 - val_accuracy: 0.9365
# Epoch 119/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6110 - accuracy: 0.7776
# Epoch 119: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6110 - accuracy: 0.7776 - val_loss: 0.2664 - val_accuracy: 0.9342
# Epoch 120/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6173 - accuracy: 0.7833
# Epoch 120: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6166 - accuracy: 0.7845 - val_loss: 0.2671 - val_accuracy: 0.9357
# Epoch 121/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6187 - accuracy: 0.7697
# Epoch 121: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 8ms/step - loss: 0.6187 - accuracy: 0.7697 - val_loss: 0.2682 - val_accuracy: 0.9365
# Epoch 122/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6302 - accuracy: 0.7682
# Epoch 122: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6323 - accuracy: 0.7669 - val_loss: 0.2685 - val_accuracy: 0.9388
# Epoch 123/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6315 - accuracy: 0.7728
# Epoch 123: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6315 - accuracy: 0.7728 - val_loss: 0.2719 - val_accuracy: 0.9403
# Epoch 124/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.7725
# Epoch 124: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6214 - accuracy: 0.7725 - val_loss: 0.2734 - val_accuracy: 0.9388
# Epoch 125/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6360 - accuracy: 0.7646
# Epoch 125: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6360 - accuracy: 0.7646 - val_loss: 0.2745 - val_accuracy: 0.9373
# Epoch 126/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6086 - accuracy: 0.7733
# Epoch 126: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6086 - accuracy: 0.7733 - val_loss: 0.2709 - val_accuracy: 0.9380
# Epoch 127/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.5869 - accuracy: 0.7937
# Epoch 127: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.5973 - accuracy: 0.7876 - val_loss: 0.2715 - val_accuracy: 0.9380
# Epoch 128/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.5902 - accuracy: 0.7802
# Epoch 128: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5933 - accuracy: 0.7789 - val_loss: 0.2676 - val_accuracy: 0.9357
# Epoch 129/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6086 - accuracy: 0.7760
# Epoch 129: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6082 - accuracy: 0.7766 - val_loss: 0.2677 - val_accuracy: 0.9373
# Epoch 130/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6102 - accuracy: 0.7739
# Epoch 130: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6235 - accuracy: 0.7702 - val_loss: 0.2615 - val_accuracy: 0.9396
# Epoch 131/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6080 - accuracy: 0.7781
# Epoch 131: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6080 - accuracy: 0.7781 - val_loss: 0.2614 - val_accuracy: 0.9426
# Epoch 132/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.5875 - accuracy: 0.7799
# Epoch 132: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5875 - accuracy: 0.7799 - val_loss: 0.2557 - val_accuracy: 0.9411
# Epoch 133/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6099 - accuracy: 0.7715
# Epoch 133: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6155 - accuracy: 0.7766 - val_loss: 0.2578 - val_accuracy: 0.9449
# Epoch 134/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6147 - accuracy: 0.7774
# Epoch 134: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6147 - accuracy: 0.7774 - val_loss: 0.2623 - val_accuracy: 0.9426
# Epoch 135/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6234 - accuracy: 0.7671
# Epoch 135: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6216 - accuracy: 0.7717 - val_loss: 0.2600 - val_accuracy: 0.9411
# Epoch 136/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.5938 - accuracy: 0.7853
# Epoch 136: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5938 - accuracy: 0.7853 - val_loss: 0.2552 - val_accuracy: 0.9396
# Epoch 137/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6283 - accuracy: 0.7693
# Epoch 137: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6253 - accuracy: 0.7702 - val_loss: 0.2614 - val_accuracy: 0.9426
# Epoch 138/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6206 - accuracy: 0.7685
# Epoch 138: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6205 - accuracy: 0.7679 - val_loss: 0.2557 - val_accuracy: 0.9480
# Epoch 139/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.6180 - accuracy: 0.7759
# Epoch 139: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6101 - accuracy: 0.7753 - val_loss: 0.2643 - val_accuracy: 0.9396
# Epoch 140/1000
# 24/31 [======================>.......] - ETA: 0s - loss: 0.6258 - accuracy: 0.7702
# Epoch 140: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6275 - accuracy: 0.7684 - val_loss: 0.2591 - val_accuracy: 0.9495
# Epoch 141/1000
# 29/31 [===========================>..] - ETA: 0s - loss: 0.6128 - accuracy: 0.7769
# Epoch 141: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6137 - accuracy: 0.7763 - val_loss: 0.2608 - val_accuracy: 0.9396
# Epoch 142/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6069 - accuracy: 0.7786
# Epoch 142: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6065 - accuracy: 0.7786 - val_loss: 0.2524 - val_accuracy: 0.9472
# Epoch 143/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6061 - accuracy: 0.7773
# Epoch 143: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.6037 - accuracy: 0.7776 - val_loss: 0.2557 - val_accuracy: 0.9411
# Epoch 144/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.6236 - accuracy: 0.7694
# Epoch 144: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6248 - accuracy: 0.7682 - val_loss: 0.2544 - val_accuracy: 0.9464
# Epoch 145/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6146 - accuracy: 0.7694
# Epoch 145: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6146 - accuracy: 0.7694 - val_loss: 0.2644 - val_accuracy: 0.9396
# Epoch 146/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6077 - accuracy: 0.7758
# Epoch 146: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6077 - accuracy: 0.7758 - val_loss: 0.2543 - val_accuracy: 0.9464
# Epoch 147/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.6041 - accuracy: 0.7695
# Epoch 147: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6068 - accuracy: 0.7692 - val_loss: 0.2597 - val_accuracy: 0.9380
# Epoch 148/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.6134 - accuracy: 0.7844
# Epoch 148: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6131 - accuracy: 0.7842 - val_loss: 0.2635 - val_accuracy: 0.9373
# Epoch 149/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.6081 - accuracy: 0.7807
# Epoch 149: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6006 - accuracy: 0.7858 - val_loss: 0.2524 - val_accuracy: 0.9396
# Epoch 150/1000
# 29/31 [===========================>..] - ETA: 0s - loss: 0.5949 - accuracy: 0.7850
# Epoch 150: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5970 - accuracy: 0.7827 - val_loss: 0.2517 - val_accuracy: 0.9403
# Epoch 151/1000
# 16/31 [==============>...............] - ETA: 0s - loss: 0.5888 - accuracy: 0.7974
# Epoch 151: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6056 - accuracy: 0.7837 - val_loss: 0.2481 - val_accuracy: 0.9510
# Epoch 152/1000
# 15/31 [=============>................] - ETA: 0s - loss: 0.5783 - accuracy: 0.7880
# Epoch 152: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5952 - accuracy: 0.7812 - val_loss: 0.2492 - val_accuracy: 0.9396
# Epoch 153/1000
# 23/31 [=====================>........] - ETA: 0s - loss: 0.6160 - accuracy: 0.7734
# Epoch 153: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6061 - accuracy: 0.7766 - val_loss: 0.2528 - val_accuracy: 0.9388
# Epoch 154/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.6036 - accuracy: 0.7758
# ...
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4750 - accuracy: 0.8248 - val_loss: 0.2602 - val_accuracy: 0.9350
# Epoch 949/1000
# 29/31 [===========================>..] - ETA: 0s - loss: 0.4770 - accuracy: 0.8322
# Epoch 949: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4746 - accuracy: 0.8327 - val_loss: 0.2725 - val_accuracy: 0.9235
# Epoch 950/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.4836 - accuracy: 0.8359
# Epoch 950: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4814 - accuracy: 0.8345 - val_loss: 0.2644 - val_accuracy: 0.9296
# Epoch 951/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.4594 - accuracy: 0.8418
# Epoch 951: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4697 - accuracy: 0.8381 - val_loss: 0.2631 - val_accuracy: 0.9250
# Epoch 952/1000
# 25/31 [=======================>......] - ETA: 0s - loss: 0.4949 - accuracy: 0.8216
# Epoch 952: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4952 - accuracy: 0.8202 - val_loss: 0.2623 - val_accuracy: 0.9304
# Epoch 953/1000
# 26/31 [========================>.....] - ETA: 0s - loss: 0.4804 - accuracy: 0.8314
# Epoch 953: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4798 - accuracy: 0.8317 - val_loss: 0.2704 - val_accuracy: 0.9235
# Epoch 954/1000
# 29/31 [===========================>..] - ETA: 0s - loss: 0.4949 - accuracy: 0.8257
# Epoch 954: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4919 - accuracy: 0.8258 - val_loss: 0.2634 - val_accuracy: 0.9296
# Epoch 955/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.4763 - accuracy: 0.8235
# Epoch 955: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4883 - accuracy: 0.8187 - val_loss: 0.2581 - val_accuracy: 0.9296
# Epoch 956/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.4905 - accuracy: 0.8255
# Epoch 956: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4897 - accuracy: 0.8243 - val_loss: 0.2610 - val_accuracy: 0.9304
# Epoch 957/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.4715 - accuracy: 0.8354
# Epoch 957: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 8ms/step - loss: 0.4867 - accuracy: 0.8286 - val_loss: 0.2549 - val_accuracy: 0.9319
# Epoch 958/1000
# 25/31 [=======================>......] - ETA: 0s - loss: 0.4763 - accuracy: 0.8306
# Epoch 958: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4819 - accuracy: 0.8286 - val_loss: 0.2534 - val_accuracy: 0.9373
# Epoch 959/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.4849 - accuracy: 0.8290
# Epoch 959: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4814 - accuracy: 0.8301 - val_loss: 0.2521 - val_accuracy: 0.9350
# Epoch 960/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.4976 - accuracy: 0.8200
# Epoch 960: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.5004 - accuracy: 0.8243 - val_loss: 0.2577 - val_accuracy: 0.9311
# Epoch 961/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.4812 - accuracy: 0.8292
# Epoch 961: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4842 - accuracy: 0.8286 - val_loss: 0.2807 - val_accuracy: 0.9220
# Epoch 962/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.4774 - accuracy: 0.8207
# Epoch 962: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4789 - accuracy: 0.8227 - val_loss: 0.2632 - val_accuracy: 0.9304
# Epoch 963/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.4990 - accuracy: 0.8234
# Epoch 963: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4998 - accuracy: 0.8235 - val_loss: 0.2668 - val_accuracy: 0.9304
# Epoch 964/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.4835 - accuracy: 0.8331
# Epoch 964: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4829 - accuracy: 0.8342 - val_loss: 0.2598 - val_accuracy: 0.9334
# Epoch 965/1000
# 25/31 [=======================>......] - ETA: 0s - loss: 0.4743 - accuracy: 0.8281
# Epoch 965: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4702 - accuracy: 0.8294 - val_loss: 0.2640 - val_accuracy: 0.9288
# Epoch 966/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.4872 - accuracy: 0.8270
# Epoch 966: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4863 - accuracy: 0.8291 - val_loss: 0.2741 - val_accuracy: 0.9281
# Epoch 967/1000
# 26/31 [========================>.....] - ETA: 0s - loss: 0.4887 - accuracy: 0.8260
# Epoch 967: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4918 - accuracy: 0.8261 - val_loss: 0.2670 - val_accuracy: 0.9296
# Epoch 968/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.4942 - accuracy: 0.8268
# Epoch 968: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4933 - accuracy: 0.8273 - val_loss: 0.2695 - val_accuracy: 0.9250
# Epoch 969/1000
# 24/31 [======================>.......] - ETA: 0s - loss: 0.4901 - accuracy: 0.8245
# Epoch 969: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4944 - accuracy: 0.8233 - val_loss: 0.2600 - val_accuracy: 0.9357
# Epoch 970/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.5002 - accuracy: 0.8253
# Epoch 970: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5014 - accuracy: 0.8245 - val_loss: 0.2547 - val_accuracy: 0.9342
# Epoch 971/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.4790 - accuracy: 0.8203
# Epoch 971: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 8ms/step - loss: 0.4803 - accuracy: 0.8207 - val_loss: 0.2601 - val_accuracy: 0.9311
# Epoch 972/1000
# 25/31 [=======================>......] - ETA: 0s - loss: 0.4730 - accuracy: 0.8288
# Epoch 972: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4808 - accuracy: 0.8238 - val_loss: 0.2706 - val_accuracy: 0.9296
# Epoch 973/1000
# 17/31 [===============>..............] - ETA: 0s - loss: 0.4754 - accuracy: 0.8313
# Epoch 973: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4881 - accuracy: 0.8291 - val_loss: 0.2689 - val_accuracy: 0.9311
# Epoch 974/1000
# 24/31 [======================>.......] - ETA: 0s - loss: 0.4742 - accuracy: 0.8317
# Epoch 974: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4757 - accuracy: 0.8296 - val_loss: 0.2653 - val_accuracy: 0.9327
# Epoch 975/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.4698 - accuracy: 0.8263
# Epoch 975: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4698 - accuracy: 0.8263 - val_loss: 0.2645 - val_accuracy: 0.9319
# Epoch 976/1000
# 23/31 [=====================>........] - ETA: 0s - loss: 0.4840 - accuracy: 0.8224
# Epoch 976: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4919 - accuracy: 0.8207 - val_loss: 0.2662 - val_accuracy: 0.9342
# Epoch 977/1000
# 26/31 [========================>.....] - ETA: 0s - loss: 0.4825 - accuracy: 0.8293
# Epoch 977: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4821 - accuracy: 0.8314 - val_loss: 0.2674 - val_accuracy: 0.9288
# Epoch 978/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.4670 - accuracy: 0.8374
# Epoch 978: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4711 - accuracy: 0.8352 - val_loss: 0.2662 - val_accuracy: 0.9273
# Epoch 979/1000
# 24/31 [======================>.......] - ETA: 0s - loss: 0.4648 - accuracy: 0.8324
# Epoch 979: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4664 - accuracy: 0.8317 - val_loss: 0.2599 - val_accuracy: 0.9334
# Epoch 980/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.4774 - accuracy: 0.8344
# Epoch 980: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4770 - accuracy: 0.8350 - val_loss: 0.2593 - val_accuracy: 0.9342
# Epoch 981/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.5010 - accuracy: 0.8221
# Epoch 981: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 8ms/step - loss: 0.5038 - accuracy: 0.8215 - val_loss: 0.2660 - val_accuracy: 0.9319
# Epoch 982/1000
# 27/31 [=========================>....] - ETA: 0s - loss: 0.5053 - accuracy: 0.8238
# Epoch 982: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5056 - accuracy: 0.8243 - val_loss: 0.2771 - val_accuracy: 0.9281
# Epoch 983/1000
# 24/31 [======================>.......] - ETA: 0s - loss: 0.4783 - accuracy: 0.8314
# Epoch 983: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4851 - accuracy: 0.8271 - val_loss: 0.2796 - val_accuracy: 0.9288
# Epoch 984/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.4904 - accuracy: 0.8229
# Epoch 984: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4914 - accuracy: 0.8230 - val_loss: 0.2717 - val_accuracy: 0.9258
# Epoch 985/1000
# 22/31 [====================>.........] - ETA: 0s - loss: 0.4918 - accuracy: 0.8267
# Epoch 985: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4890 - accuracy: 0.8256 - val_loss: 0.2786 - val_accuracy: 0.9288
# Epoch 986/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.4776 - accuracy: 0.8242
# Epoch 986: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4792 - accuracy: 0.8235 - val_loss: 0.2635 - val_accuracy: 0.9342
# Epoch 987/1000
# 23/31 [=====================>........] - ETA: 0s - loss: 0.4956 - accuracy: 0.8210
# Epoch 987: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4890 - accuracy: 0.8235 - val_loss: 0.2773 - val_accuracy: 0.9296
# Epoch 988/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.4894 - accuracy: 0.8260
# Epoch 988: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4919 - accuracy: 0.8245 - val_loss: 0.2640 - val_accuracy: 0.9327
# Epoch 989/1000
# 23/31 [=====================>........] - ETA: 0s - loss: 0.4771 - accuracy: 0.8325
# Epoch 989: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 9ms/step - loss: 0.4901 - accuracy: 0.8268 - val_loss: 0.2695 - val_accuracy: 0.9334
# Epoch 990/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.4823 - accuracy: 0.8270
# Epoch 990: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4886 - accuracy: 0.8245 - val_loss: 0.2728 - val_accuracy: 0.9288
# Epoch 991/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.4991 - accuracy: 0.8200
# Epoch 991: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5012 - accuracy: 0.8197 - val_loss: 0.2779 - val_accuracy: 0.9250
# Epoch 992/1000
# 21/31 [===================>..........] - ETA: 0s - loss: 0.4972 - accuracy: 0.8129
# Epoch 992: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4929 - accuracy: 0.8197 - val_loss: 0.2747 - val_accuracy: 0.9296
# Epoch 993/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.4900 - accuracy: 0.8240
# Epoch 993: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4905 - accuracy: 0.8230 - val_loss: 0.2733 - val_accuracy: 0.9250
# Epoch 994/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.4898 - accuracy: 0.8292
# Epoch 994: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4885 - accuracy: 0.8289 - val_loss: 0.2688 - val_accuracy: 0.9319
# Epoch 995/1000
# 30/31 [============================>.] - ETA: 0s - loss: 0.4927 - accuracy: 0.8201
# Epoch 995: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4929 - accuracy: 0.8199 - val_loss: 0.2715 - val_accuracy: 0.9319
# Epoch 996/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.4706 - accuracy: 0.8284
# Epoch 996: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4719 - accuracy: 0.8284 - val_loss: 0.2591 - val_accuracy: 0.9396
# Epoch 997/1000
# 24/31 [======================>.......] - ETA: 0s - loss: 0.4846 - accuracy: 0.8291
# Epoch 997: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4809 - accuracy: 0.8337 - val_loss: 0.2733 - val_accuracy: 0.9235
# Epoch 998/1000
# 31/31 [==============================] - ETA: 0s - loss: 0.4770 - accuracy: 0.8258
# Epoch 998: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4770 - accuracy: 0.8258 - val_loss: 0.2776 - val_accuracy: 0.9243
# Epoch 999/1000
# 23/31 [=====================>........] - ETA: 0s - loss: 0.5083 - accuracy: 0.8274
# Epoch 999: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 8ms/step - loss: 0.4950 - accuracy: 0.8281 - val_loss: 0.2698 - val_accuracy: 0.9281
# Epoch 1000/1000
# 28/31 [==========================>...] - ETA: 0s - loss: 0.4806 - accuracy: 0.8337
# Epoch 1000: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 31/31 [==============================] - 0s 7ms/step - loss: 0.4776 - accuracy: 0.8360 - val_loss: 0.2772 - val_accuracy: 0.9273

# %%
# Model evaluation
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2772 - accuracy: 0.9273

# %%
# Loading the saved model
model = tf.keras.models.load_model(model_save_path)

# %%
# Inference test
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 1s 627ms/step
# [3.4917612e-02 1.8771949e-01 7.4390340e-01 5.9987146e-05 3.3399567e-02]
# 2

# %% [markdown]
# # Confusion matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 41/41 [==============================] - 0s 2ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       406
#            1       0.94      0.87      0.90       377
#            2       0.89      0.97      0.93       338
#            3       0.99      0.98      0.98        83
#            4       0.99      0.68      0.80       103
#
#     accuracy                           0.93      1307
#    macro avg       0.95      0.90      0.92      1307
# weighted avg       0.93      0.93      0.93      1307

# %% [markdown]
# # Convert to model for Tensorflow-Lite

# %%
# Save as a model dedicated to inference
model.save(model_save_path, include_optimizer=False)
# Out:
# /home/deadsoul/.local/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Transform model (quantization)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp3fvq26kf/assets
# INFO:tensorflow:Assets written to: /tmp/tmp3fvq26kf/assets
# 2024-05-04 23:46:50.271864: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-05-04 23:46:50.271921: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-05-04 23:46:50.272348: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp3fvq26kf
# 2024-05-04 23:46:50.274249: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-05-04 23:46:50.274288: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp3fvq26kf
# 2024-05-04 23:46:50.278513: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2024-05-04 23:46:50.279953: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-05-04 23:46:50.333212: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp3fvq26kf
# 2024-05-04 23:46:50.346003: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 73655 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 6, Total Ops 13, % non-converted = 46.15 %
#  * 6 ARITH ops
#
# - arith.constant:    6 occurrences  (f32: 6)
#
#
#
#   (f32: 3)
#   (f32: 1)
# 6588

# %% [markdown]
# # Inference test

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# Get I / O tensor
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# Inference implementation
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: user 104 µs, sys: 0 ns, total: 104 µs
# Wall time: 285 µs

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [3.4917627e-02 1.8771958e-01 7.4390328e-01 5.9987142e-05 3.3399560e-02]
# 2
